# %% [markdown]
# # 轨迹分析
# 对比 CQL vs Safe CQL 的 ODE 曲线，展示 Safe CQL 在 I 接近 0.3 时主动降剂量。

# %%
import sys
sys.path.insert(0, '..')
import numpy as np
import matplotlib.pyplot as plt
from env.chemo_env import step_ode, DEFAULT_PARAMS, X0, DT, MAX_STEPS

# TODO: 加载 policy，rollout，绘制 N,T,I,C 曲线
plt.axhline(0.3, color='r', linestyle='--', label='I_SAFE')
plt.legend()
plt.show()
