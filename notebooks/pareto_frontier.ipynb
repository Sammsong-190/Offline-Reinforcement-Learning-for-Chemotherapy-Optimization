# %% [markdown]
# # Pareto Frontier
# X轴: 平均免疫水平 | Y轴: 肿瘤杀灭率
# Safe CQL 应在最优前沿上。

# %%
import sys
sys.path.insert(0, '..')
import numpy as np
import matplotlib.pyplot as plt

# TODO: 评估多种策略，收集 (avg_I, tumor_clear%)，绘制 Pareto Frontier
plt.xlabel('Avg Immune Level')
plt.ylabel('Tumor Clear %')
plt.show()
